# %% [markdown]
# # Get reports-2017-2019.xlsx

# %% [markdown]
# ### save to “df_companies"

# %%
import pandas as pd

# 读取文件中的 "companies" sheet
df_companies = pd.read_excel("reports-2017-2019.xlsx", sheet_name="annual 2017-2019")


# 查看前几行，确认结构
df_companies.head()
# Out:
#           conml  predicted_report_year predicted_report_type  loc  \
# 0        1&1 AG                   2017         annual report  NaN
# 1        1&1 AG                   2018         annual report  NaN
# 2        1&1 AG                   2019         annual report  NaN
# 3  3I Group PLC                   2017         annual report  GBR
# 4  3I Group PLC                   2018         annual report  GBR
#
#   GICS_level_1        GICS_level_2  \
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2          NaN                 NaN
# 3   Financials  Financial Services
# 4   Financials  Financial Services
#
#                                       pdf_local_path  \
# 0  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
# 1  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
# 2  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
# 3  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
# 4  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
#
#                                               pdfurl  n_tokenised_sentences  \
# 0  https://imagepool.1und1.ag/v2/download/bericht...                 6185.0
# 1  https://imagepool.1und1.ag/v2/download/bericht...                 7222.0
# 2  https://imagepool.1und1.ag/v2/download/bericht...                 6387.0
# 3  https://www.3i.com/media/1849/3i-group-ar-2017...                 7533.0
# 4  https://www.3i.com/media/jx2hhaxx/3i-group-ar-...                 6399.0
#
#    n_predicted_initiatives clean_conml
# 0                      0.0        11ag
# 1                      0.0        11ag
# 2                      0.0        11ag
# 3                      1.0          3i
# 4                      1.0          3i

# %% [markdown]
# ### read "conml" column

# %%
# 提取所有非空且唯一的公司名，放入一个列表变量中
company_full_names = df_companies['conml'].dropna().unique().tolist()
# 打印公司名列表的长度和前10个公司名
print(f"Number of unique company names: {len(company_full_names)}")
print("First 10 company names:", company_full_names[:10])
# Out:
# Number of unique company names: 198
# First 10 company names: ['1&1 AG', '3I Group PLC', 'Abengoa SA', 'AIA Group Limited', 'Air Canada', 'Aixtron SE', 'Aker ASA', 'Aker Solutions ASA', 'Amundi SA', 'Antofagasta PLC']

# %% [markdown]
# ### create empty DataFrame

# %%
import pandas as pd

# 初始化元数据表
company_metadata = pd.DataFrame({'company_name': company_full_names})

# 添加你要补全的字段（先设为空）
fields = ['sector', 'industry', 'country', 'ticker', 'website', 'ISIN','Number of employees']
for field in fields:
    company_metadata[field] = None

# %% [markdown]
# # yfinance

# %% [markdown]
# ### use yfinance to find ticker

# %%
import requests

def guess_ticker(company_name):
    url = f"https://query2.finance.yahoo.com/v1/finance/search?q={company_name}"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    try:
        r = requests.get(url, headers=headers)  # 加 headers
        data = r.json()
        if data['quotes']:
            return data['quotes'][0]['symbol']
    except Exception as e:
        print(f"Error for {company_name}: {e}")
    return None

# %%
import time

# 遍历 company_metadata 表，为每家公司匹配 ticker
for i, row in company_metadata.iterrows():
    company_name = row['company_name']
    ticker = guess_ticker(company_name)
    company_metadata.at[i, 'ticker'] = ticker
    print(f"{i+1}/{len(company_metadata)}: {company_name} -> {ticker}")
    
    # 防止触发 Yahoo 限速限制（建议加个小延迟）
    time.sleep(0.5)
# Out:
# 1/198: 1&1 AG -> SB=F
# 2/198: 3I Group PLC -> TGOPY
# 3/198: Abengoa SA -> AGOAF
# 4/198: AIA Group Limited -> 7A20.F
# 5/198: Air Canada -> AC.TO
# 6/198: Aixtron SE -> AIXAD.XC
# 7/198: Aker ASA -> FKM.F
# 8/198: Aker Solutions ASA -> 1AKA.F
# 9/198: Amundi SA -> AMUN.VI
# 10/198: Antofagasta PLC -> ANFGF
# 11/198: Antofagasta plc -> ANFGF
# 12/198: Arcelormittal SA -> MT.AS
# 13/198: ArcelorMittal SA -> MT.AS
# 14/198: Aroundtown SA -> 0RUH.IL
# 15/198: AstraZeneca PLC -> AZN
# 16/198: Atea ASA -> MKL.F
# 17/198: Atos SE -> ATO.PA
# 18/198: AT&T Inc -> T
# 19/198: AT&T Corp -> T
# 20/198: Aurizon Holdings Ltd -> QRL.F
# 21/198: Aviva plc -> AV.L
# 22/198: Banco Santander, S.A. -> SAN
# 23/198: Banco Santander ( Brasil ) S.A. -> BSBR
# 24/198: BANDAI NAMCO Holdings Inc -> 7832.T
# 25/198: Barrick Gold Corp -> ABR.BE
# 26/198: BCE Inc. -> BCE
# 27/198: Beach Energy Ltd -> BCHEY
# 28/198: Bertelsmann SE & Co. KGaA -> BTG4.F
# 29/198: Bertelsmann SE & Co KGaA -> BTG4.F
# 30/198: bioMérieux -> None
# 31/198: bioMérieux S.A. -> None
# 32/198: Blackmores Limited -> None
# 33/198: Bobst Group SA -> None
# 34/198: Boston Scientific Corporation -> BSX
# 35/198: Brambles Ltd -> R1H.F
# 36/198: Bucher Industries AG, Niederweningen -> BUHA.F
# 37/198: Catella -> SKVB.F
# 38/198: Cathay Pacific Airways Ltd -> CTY.F
# 39/198: Cathay Pacific Airways Limited -> CPCAF
# 40/198: CEWE Stiftung & Co KGAA -> CWC.F
# 41/198: Challenger Limited -> CGF.AX
# 42/198: Challenger Ltd -> GK9.F
# 43/198: Chevron Corp -> CVX
# 44/198: Chevron Corporation -> CVX
# 45/198: China Airlines, Ltd. -> 2610.TW
# 46/198: China Minsheng Banking Corp -> CGMBF
# 47/198: China National Petroleum Corporation -> None
# 48/198: Citigroup Inc. -> C
# 49/198: Cnooc Ltd -> None
# 50/198: Coloplast A/S -> CLPBY
# 51/198: Coloplast A / S -> CLPBY
# 52/198: Consolidated Edison, Inc. -> ED
# 53/198: Co-operative Group Limited -> FCG.NZ
# 54/198: Covivio -> COV.PA
# 55/198: CRH PLC -> CRH
# 56/198: CRH plc -> CRH
# 57/198: Croda International Plc -> CRDA.L
# 58/198: Croda International PLC -> CRDA.L
# 59/198: Cromwell Property Group -> CMW.AX
# 60/198: CRRC Corporation Ltd -> None
# 61/198: CRRC Group -> None
# 62/198: De’Longhi S.p.A. -> None
# 63/198: De’ Longhi S.p.A. -> DLN.F
# 64/198: Deutsche Bank AG -> DB
# 65/198: Deutsche Telekom AG -> DTE.DE
# 66/198: Diageo -> DEO
# 67/198: Diageo plc -> DEO
# 68/198: DKSH Holding AG -> DS5.F
# 69/198: DMG MORI AG -> GIL.VI
# 70/198: Dominion Energy, Inc. -> D
# 71/198: Dominion Energy Inc -> D
# 72/198: DormaKaba Holding AG -> KABN.F
# 73/198: Downer Edi Ltd -> DNE.F
# 74/198: Eni SpA -> E
# 75/198: E.ON SE -> EOAN.DE
# 76/198: Fenix Outdoor AB -> None
# 77/198: Fenix Outdoor International AG -> 0QVE.L
# 78/198: Ferrari N.V. -> RACE
# 79/198: Fomento de Construcciones y Contratas, S.A. -> FCC.MC
# 80/198: FOMENTO DE CONSTRUCCIONES Y CONTRATAS , S.A. -> FCC.MC
# 81/198: Ford Motor Co -> F
# 82/198: Fraport AG -> FRAS.F
# 83/198: Glencore plc -> GLNCY
# 84/198: Hannover Rück SE -> None
# 85/198: HeidelbergCement AG -> HEI.MU
# 86/198: Hexpol AB -> 4QT1.F
# 87/198: Hong Kong Exchanges and Clearing Ltd -> HK2C.SG
# 88/198: HSBC Bank Canada -> None
# 89/198: Husqvarna AB -> HRZ.F
# 90/198: Hydro-Québec -> None
# 91/198: IEA Bioenergy -> None
# 92/198: Iluka Resources Ltd -> ILKAY
# 93/198: Infineon Technologies AG -> IFX.DE
# 94/198: Informa PLC -> IEA.F
# 95/198: Infosys Limited -> INFY
# 96/198: Inpex Corporation -> IPXHY
# 97/198: Interfor Corp -> 8IF1.F
# 98/198: International Business Machines Corp -> IBM
# 99/198: International Business Machines Corporation -> IBM
# 100/198: Intesa Sanpaolo S.p.A. -> ISP.MI
# 101/198: Itron Inc -> ITRI
# 102/198: JPMorgan Chase & Co -> JPM
# 103/198: JPMorgan Chase & Co. -> JPM
# 104/198: Kao Corp -> KAOOY
# 105/198: Kapsch Trafficcom AG -> 0GTO.L
# 106/198: Knorr-Bremse AG -> KBXA.F
# 107/198: Knorr - Bremse AG -> KBXA.F
# 108/198: Kone OYJ -> KNEBV.HE
# 109/198: KONE Corporation -> KNEBV.HE
# 110/198: Koppers Holdings Inc -> KOP
# 111/198: Kordsa Teknik Tekstil A S -> None
# 112/198: Kosmos Energy Ltd -> KOS
# 113/198: Kuehne & Nagel International Ag, Schindellegi -> KHNGY
# 114/198: Kureha Corporation -> 0K1.F
# 115/198: Landis & Gyr AG -> LANDZ.XC
# 116/198: Lear Corp -> LEA
# 117/198: Leonardo -> DRS
# 118/198: Leonardo S.p.a. -> FMNB.F
# 119/198: Lockheed Martin Corp -> LMT
# 120/198: Lpp S.A., Gdansk -> 1RY.F
# 121/198: LyondellBasell Industries NV -> LYB
# 122/198: Man SE -> NMSCA
# 123/198: Mapfre -> MAPE.XC
# 124/198: Maple Leaf Foods Inc -> MFI.TO
# 125/198: MİGROS TİCARET A.Ş. -> None
# 126/198: Migros Ticaret A.Ş. -> MGROS.IS
# 127/198: Mitsubishi Heavy Industries Ltd -> MHVYF
# 128/198: Mitsui & Co Ltd -> SMFG
# 129/198: Monash Health -> None
# 130/198: Morguard Corp -> 74S.F
# 131/198: National Australia Bank Ltd -> NAL.F
# 132/198: Nestle SA, Cham Und Vevey -> NESM.MU
# 133/198: Netcompany A/S -> None
# 134/198: Nikon Corp -> 7731.T
# 135/198: Nordex SE -> NDX1.F
# 136/198: Orient Overseas ( International ) Limited -> OROVY
# 137/198: Ping An Bank Co Ltd -> None
# 138/198: Preem Norge As -> None
# 139/198: PVH Corp -> PVH
# 140/198: Ramsay Health Care Ltd -> RMY.F
# 141/198: Repsol, S.A. -> REP.MC
# 142/198: Rosenbauer International AG, Leonding -> ROI.DE
# 143/198: Royal Bank of Canada -> RY.TO
# 144/198: R Stahl AG, Waldenburg -> RSL2.F
# 145/198: Sacyr SA -> 0OFU.IL
# 146/198: Schlumberger Ltd -> SLB
# 147/198: Schlumberger N.V. -> SLB
# 148/198: Schroders -> HSWYX
# 149/198: Schroders PLC -> PYXB.F
# 150/198: Schroders plc -> PYXB.F
# 151/198: Seneca Foods Corp. -> SENEA
# 152/198: Sentara Healthcare -> None
# 153/198: Sentara Hospitals -> None
# 154/198: Shanghai Fosun Pharmaceutical (Group) Co Ltd -> 08HH.F
# 155/198: Shanghai Fosun Pharmaceutical ( Group ) Co. , Ltd. -> 08HH.F
# 156/198: Sibanye-Stillwater Limited -> SBSW
# 157/198: Singapore Airlines Limited -> C6L.SI
# 158/198: Smith & Nephew plc -> SMSI
# 159/198: Smith & Nephew PLC -> SMSI
# 160/198: Softbank Group Corp -> 9984.T
# 161/198: SoftBank Group Corp. -> 9984.T
# 162/198: Sony Group Corporation -> SONY
# 163/198: Southwest Airlines Co. -> LUV
# 164/198: Stantec Inc. -> STN
# 165/198: Stantec Inc -> STN
# 166/198: Suncor Energy Inc. -> SU
# 167/198: Sun Pharmaceutical Industries Ltd. -> None
# 168/198: Sun Pharmaceutical Industries Limited -> SUNPHARMA.BO
# 169/198: Swire Properties Limited -> SW9.F
# 170/198: Taikisha Ltd -> 1979.T
# 171/198: TECHNOGYM S.p.A. -> TN2.F
# 172/198: Technogym S.p.A. -> TN2.F
# 173/198: Tecnicas Reunidas -> T5R.F
# 174/198: Técnicas Reunidas, S.A. -> PBR
# 175/198: Telenor ASA -> TEL.OL
# 176/198: Telstra Corporation Limited -> None
# 177/198: Telstra Corporation Ltd -> None
# 178/198: Tenaris SA, Luxembourg -> TS
# 179/198: Toyota Motor Corporation -> TM
# 180/198: TUI AG -> TUI1.DE
# 181/198: UnipolSai Assicurazioni S.p.A. -> None
# 182/198: UnipolSai Assicurazioni -> None
# 183/198: U.S. Environmental Protection Agency -> None
# 184/198: Vale SA -> CVLB.SG
# 185/198: Vale S.A. -> VALE
# 186/198: VALE S.A. -> VALE
# 187/198: Villeroy & Boch AG -> VIB3.F
# 188/198: Visa Inc. -> V
# 189/198: Visa Inc -> V
# 190/198: Vodafone Group Plc -> VOD
# 191/198: Wm Morrison Supermarkets PLC -> None
# 192/198: Woodside Petroleum Ltd -> US9802283088.SG
# 193/198: World Bank -> 0P0001CO7N
# 194/198: World Bank Group -> None
# 195/198: World Economic Forum -> None
# 196/198: Worldline -> WO60.F
# 197/198: Yara International ASA -> IU2.F
# 198/198: ZF Friedrichshafen AG -> None

# %% [markdown]
# ### ticker saved in "company_metadata.csv"

# %%
company_metadata.csvcompany_metadata.to_csv("", index=False)

# %% [markdown]
# check missing

# %%
# 检查有多少行 ticker 是空的
missing_ticker_count = company_metadata['ticker'].isna().sum()
print(f"Companies without ticker: {missing_ticker_count} / {len(company_metadata)}")
# Out:
# Companies without ticker: 32 / 198

# %% [markdown]
# ### use yfinance to fill sector, country, website, etc.

# %%
import yfinance as yf

def get_yfinance_info(ticker):
    try:
        info = yf.Ticker(ticker).info
        return {
            'sector': info.get('sector'),
            'industry': info.get('industry'),
            'country': info.get('country'),
            'website': info.get('website'),
            'ISIN': info.get('isin'),
            'Number of employees': info.get('fullTimeEmployees')
        }
    except Exception as e:
        print(f"Error getting info for {ticker}: {e}")
        return {}

# %%
import time

for i, row in company_metadata.iterrows():
    ticker = row['ticker']
    if pd.notna(ticker):
        meta = get_yfinance_info(ticker)
        for key in ['sector','industry', 'country', 'website','ISIN', 'Number of employees']:
            company_metadata.at[i, key] = meta.get(key)
        print(f"{i+1}/{len(company_metadata)}: {row['company_name']} get")
        time.sleep(0.5)  # 防止被限速
# Out:
# 1/198: 1&1 AG get
# 2/198: 3I Group PLC get
# 3/198: Abengoa SA get
# 4/198: AIA Group Limited get
# 5/198: Air Canada get
# 6/198: Aixtron SE get
# 7/198: Aker ASA get
# 8/198: Aker Solutions ASA get
# 9/198: Amundi SA get
# 10/198: Antofagasta PLC get
# 11/198: Antofagasta plc get
# 12/198: Arcelormittal SA get
# 13/198: ArcelorMittal SA get
# 14/198: Aroundtown SA get
# 15/198: AstraZeneca PLC get
# 16/198: Atea ASA get
# 17/198: Atos SE get
# 18/198: AT&T Inc get
# 19/198: AT&T Corp get
# 20/198: Aurizon Holdings Ltd get
# 21/198: Aviva plc get
# 22/198: Banco Santander, S.A. get
# 23/198: Banco Santander ( Brasil ) S.A. get
# 24/198: BANDAI NAMCO Holdings Inc get
# 25/198: Barrick Gold Corp get
# 26/198: BCE Inc. get
# 27/198: Beach Energy Ltd get
# 28/198: Bertelsmann SE & Co. KGaA get
# 29/198: Bertelsmann SE & Co KGaA get
# 34/198: Boston Scientific Corporation get
# 35/198: Brambles Ltd get
# 36/198: Bucher Industries AG, Niederweningen get
# 37/198: Catella get
# 38/198: Cathay Pacific Airways Ltd get
# 39/198: Cathay Pacific Airways Limited get
# 40/198: CEWE Stiftung & Co KGAA get
# 41/198: Challenger Limited get
# 42/198: Challenger Ltd get
# 43/198: Chevron Corp get
# 44/198: Chevron Corporation get
# 45/198: China Airlines, Ltd. get
# 46/198: China Minsheng Banking Corp get
# 48/198: Citigroup Inc. get
# 50/198: Coloplast A/S get
# 51/198: Coloplast A / S get
# 52/198: Consolidated Edison, Inc. get
# 53/198: Co-operative Group Limited get
# 54/198: Covivio get
# 55/198: CRH PLC get
# 56/198: CRH plc get
# 57/198: Croda International Plc get
# 58/198: Croda International PLC get
# 59/198: Cromwell Property Group get
# 63/198: De’ Longhi S.p.A. get
# 64/198: Deutsche Bank AG get
# 65/198: Deutsche Telekom AG get
# 66/198: Diageo get
# 67/198: Diageo plc get
# 68/198: DKSH Holding AG get
# 69/198: DMG MORI AG get
# 70/198: Dominion Energy, Inc. get
# 71/198: Dominion Energy Inc get
# 72/198: DormaKaba Holding AG get
# 73/198: Downer Edi Ltd get
# 74/198: Eni SpA get
# 75/198: E.ON SE get
# 77/198: Fenix Outdoor International AG get
# 78/198: Ferrari N.V. get
# 79/198: Fomento de Construcciones y Contratas, S.A. get
# 80/198: FOMENTO DE CONSTRUCCIONES Y CONTRATAS , S.A. get
# 81/198: Ford Motor Co get
# 82/198: Fraport AG get
# 83/198: Glencore plc get
# 85/198: HeidelbergCement AG get
# 86/198: Hexpol AB get
# 87/198: Hong Kong Exchanges and Clearing Ltd get
# 89/198: Husqvarna AB get
# 92/198: Iluka Resources Ltd get
# 93/198: Infineon Technologies AG get
# 94/198: Informa PLC get
# 95/198: Infosys Limited get
# 96/198: Inpex Corporation get
# 97/198: Interfor Corp get
# 98/198: International Business Machines Corp get
# 99/198: International Business Machines Corporation get
# 100/198: Intesa Sanpaolo S.p.A. get
# 101/198: Itron Inc get
# 102/198: JPMorgan Chase & Co get
# 103/198: JPMorgan Chase & Co. get
# 104/198: Kao Corp get
# 105/198: Kapsch Trafficcom AG get
# 106/198: Knorr-Bremse AG get
# 107/198: Knorr - Bremse AG get
# 108/198: Kone OYJ get
# 109/198: KONE Corporation get
# 110/198: Koppers Holdings Inc get
# 112/198: Kosmos Energy Ltd get
# 113/198: Kuehne & Nagel International Ag, Schindellegi get
# 114/198: Kureha Corporation get
# 115/198: Landis & Gyr AG get
# 116/198: Lear Corp get
# 117/198: Leonardo get
# 118/198: Leonardo S.p.a. get
# 119/198: Lockheed Martin Corp get
# 120/198: Lpp S.A., Gdansk get
# 121/198: LyondellBasell Industries NV get
# 122/198: Man SE get
# 123/198: Mapfre get
# 124/198: Maple Leaf Foods Inc get
# 126/198: Migros Ticaret A.Ş. get
# 127/198: Mitsubishi Heavy Industries Ltd get
# 128/198: Mitsui & Co Ltd get
# 130/198: Morguard Corp get
# 131/198: National Australia Bank Ltd get
# 132/198: Nestle SA, Cham Und Vevey get
# 134/198: Nikon Corp get
# 135/198: Nordex SE get
# 136/198: Orient Overseas ( International ) Limited get
# 139/198: PVH Corp get
# 140/198: Ramsay Health Care Ltd get
# 141/198: Repsol, S.A. get
# 142/198: Rosenbauer International AG, Leonding get
# 143/198: Royal Bank of Canada get
# 144/198: R Stahl AG, Waldenburg get
# 145/198: Sacyr SA get
# 146/198: Schlumberger Ltd get
# 147/198: Schlumberger N.V. get
# 148/198: Schroders get
# 149/198: Schroders PLC get
# 150/198: Schroders plc get
# 151/198: Seneca Foods Corp. get
# 154/198: Shanghai Fosun Pharmaceutical (Group) Co Ltd get
# 155/198: Shanghai Fosun Pharmaceutical ( Group ) Co. , Ltd. get
# 156/198: Sibanye-Stillwater Limited get
# 157/198: Singapore Airlines Limited get
# 158/198: Smith & Nephew plc get
# 159/198: Smith & Nephew PLC get
# 160/198: Softbank Group Corp get
# 161/198: SoftBank Group Corp. get
# 162/198: Sony Group Corporation get
# 163/198: Southwest Airlines Co. get
# 164/198: Stantec Inc. get
# 165/198: Stantec Inc get
# 166/198: Suncor Energy Inc. get
# 168/198: Sun Pharmaceutical Industries Limited get
# 169/198: Swire Properties Limited get
# 170/198: Taikisha Ltd get
# 171/198: TECHNOGYM S.p.A. get
# 172/198: Technogym S.p.A. get
# 173/198: Tecnicas Reunidas get
# 174/198: Técnicas Reunidas, S.A. get
# 175/198: Telenor ASA get
# 178/198: Tenaris SA, Luxembourg get
# 179/198: Toyota Motor Corporation get
# 180/198: TUI AG get
# 184/198: Vale SA get
# 185/198: Vale S.A. get
# 186/198: VALE S.A. get
# 187/198: Villeroy & Boch AG get
# 188/198: Visa Inc. get
# 189/198: Visa Inc get
# 190/198: Vodafone Group Plc get
# 192/198: Woodside Petroleum Ltd get
# 193/198: World Bank get
# 196/198: Worldline get
# 197/198: Yara International ASA get

# %% [markdown]
# add a column source as: yfinance

# %%
company_metadata['source'] = company_metadata['sector'].apply(
    lambda x: 'yfinance' if pd.notna(x) and str(x).strip() != "" else None
)

# %% [markdown]
# add a column as: status

# %% [markdown]
# If any required field is null (NaN) or an empty string, it is marked as 'missing'
#
# Only when all 6 fields have valid values ​​is it marked as 'matched'

# %%
# 明确列出你要检查的字段（不包括 ISIN）
required_fields = ['sector', 'industry', 'country', 'ticker', 'website', 'Number of employees']

def lookup_status(row):
    for field in required_fields:
        value = row.get(field)
        if pd.isna(value) or str(value).strip() == "":
            return 'missing'
    return 'matched'

company_metadata['lookup_status'] = company_metadata.apply(lookup_status, axis=1)

# %%
missing_count = company_metadata[company_metadata['lookup_status'] == 'missing'].shape[0]
print(f"Number of companies with missing metadata: {missing_count}")
# Out:
# Number of companies with missing metadata: 63

# %%
match_count = company_metadata[company_metadata['lookup_status'] == 'matched'].shape[0]
print(f"Number of companies with matched metadata: {match_count}")
# Out:
# Number of companies with matched metadata: 135

# %%
company_metadata.to_csv("company_metadata.csv", index=False)

# %% [markdown]
# ### save all the lookup_status == 'missing' row to "company_metadata_missing_only.csv"

# %%
missing_rows = company_metadata[company_metadata['lookup_status'] == 'missing']
missing_rows.to_csv("company_metadata_missing_only.csv", index=False)

# %% [markdown]
# # OpenCorporates

# %% [markdown]
# ### use open corporates to fill the table：

# %% [markdown]
# only use "company_metadata_missing_only.csv"

# %% [markdown]
# check if missing, if true, add country, website, source

# %%
import pandas as pd
import time
import requests
import os
from dotenv import load_dotenv

# 加载 API Key
load_dotenv()
API_KEY = os.getenv("OPENCORP_API_KEY")

# 读取只包含 missing 的公司表
missing_df = pd.read_csv("company_metadata_missing_only.csv")

# 定义调用 OpenCorporates API 的函数
def search_company_opencorp(name):
    url = f"https://api.opencorporates.com/v0.4/companies/search?q={name}&api_token={API_KEY}"
    try:
        response = requests.get(url)
        if response.status_code != 200:
            return {}
        data = response.json()
        if data["results"]["companies"]:
            c = data["results"]["companies"][0]["company"]
            return {
                "country": c.get("jurisdiction_code", "").upper(),
                "website": c.get("homepage_url", ""),
                "source": "opencorporates"
            }
    except Exception as e:
        print(f"Error for {name}: {e}")
    return {}

# 遍历每一行进行补充
for i, row in missing_df.iterrows():
    if pd.isna(row['country']) or pd.isna(row['website']) or str(row['country']).strip() == "" or str(row['website']).strip() == "":
        result = search_company_opencorp(row['company_name'])
        if result:
            if result.get("country"):
                missing_df.at[i, 'country'] = result["country"]
            if result.get("website"):
                missing_df.at[i, 'website'] = result["website"]
            missing_df.at[i, 'source'] = result["source"]
        print(f"{i+1}/{len(missing_df)}: {row['company_name']} get")
        time.sleep(1.2)
# Out:
# 1/63: 1&1 AG get
# 4/63: Barrick Gold Corp get
# 8/63: bioMérieux get
# 9/63: bioMérieux S.A. get
# 10/63: Blackmores Limited get
# 11/63: Bobst Group SA get
# 13/63: China National Petroleum Corporation get
# 14/63: Cnooc Ltd get
# 16/63: CRRC Corporation Ltd get
# 17/63: CRRC Group get
# 18/63: De’Longhi S.p.A. get
# 19/63: Fenix Outdoor AB get
# 21/63: Hannover Rück SE get
# 22/63: HeidelbergCement AG get
# 23/63: Hong Kong Exchanges and Clearing Ltd get
# 24/63: HSBC Bank Canada get
# 25/63: Hydro-Québec get
# 26/63: IEA Bioenergy get
# 28/63: Kordsa Teknik Tekstil A S get
# 30/63: MİGROS TİCARET A.Ş. get
# 33/63: Monash Health get
# 35/63: Nestle SA, Cham Und Vevey get
# 36/63: Netcompany A/S get
# 38/63: Ping An Bank Co Ltd get
# 39/63: Preem Norge As get
# 40/63: Schroders get
# 41/63: Sentara Healthcare get
# 42/63: Sentara Hospitals get
# 47/63: Sun Pharmaceutical Industries Ltd. get
# 50/63: Telstra Corporation Limited get
# 51/63: Telstra Corporation Ltd get
# 52/63: UnipolSai Assicurazioni S.p.A. get
# 53/63: UnipolSai Assicurazioni get
# 54/63: U.S. Environmental Protection Agency get
# 55/63: Vale SA get
# 58/63: Wm Morrison Supermarkets PLC get
# 59/63: Woodside Petroleum Ltd get
# 60/63: World Bank get
# 61/63: World Bank Group get
# 62/63: World Economic Forum get
# 63/63: ZF Friedrichshafen AG get

# %% [markdown]
# Expand country abbreviations to full names

# %%
import pycountry

def convert_country_code(code):
    if not code or not isinstance(code, str):
        return code
    code = code.strip().split("_")[0]
    country = pycountry.countries.get(alpha_2=code.upper())
    return country.name if country else code

# %%
missing_df['country'] = missing_df['country'].apply(convert_country_code)

# %% [markdown]
# save to "company_metadata_missing_updated.csv"

# %%
# 保存更新后的文件
missing_df.to_csv("company_metadata_missing_updated.csv", index=False)

# %%
# 读取主表和更新的缺失子表
company_metadata = pd.read_csv("company_metadata.csv")
updated_missing = pd.read_csv("company_metadata_missing_updated.csv")

# %% [markdown]
# combine company_metadata_missing_updated.csv to company_metadata.csv

# %%
# 合并两个表（只保留两列用于比较）
merged = pd.merge(
    company_metadata[['company_name', 'country', 'website']],
    updated_missing [['company_name', 'country', 'website']],
    on='company_name',
    suffixes=('_main', '_updated')
)

# 检查两个字段的冲突（都非空且不同）
conflict_rows = merged[
    (
        merged['country_main'].notna() & merged['country_updated'].notna() &
        (merged['country_main'].str.strip() != merged['country_updated'].str.strip())
    ) |
    (
        merged['website_main'].notna() & merged['website_updated'].notna() &
        (merged['website_main'].str.strip() != merged['website_updated'].str.strip())
    )
]

# 查看冲突公司
print(f"Number of conflicts: {len(conflict_rows)}")
print(conflict_rows[['company_name', 'country_main', 'country_updated', 'website_main', 'website_updated']])

# 可选：保存冲突报告
conflict_rows.to_csv("country_website_conflicts.csv", index=False)
# Out:
# Number of conflicts: 0
# Empty DataFrame
# Columns: [company_name, country_main, country_updated, website_main, website_updated]
# Index: []

# %%
# 根据 company_name 进行合并更新（以 updated_missing 为准）
company_metadata.set_index('company_name', inplace=True)
updated_missing.set_index('company_name', inplace=True)

# 用更新后的字段覆盖原表中的相应行（只会改掉有值的）
company_metadata.update(updated_missing)

# 恢复索引
company_metadata.reset_index(inplace=True)

# 保存合并后的总表
company_metadata.to_csv("company_metadata.csv", index=False)

# %% [markdown]
# still missing

# %%
# 查看每列缺失值数量
missing_counts = company_metadata.isna().sum()

# 打印结果
print("各列缺失值统计：")
print(missing_counts)
# Out:
# 各列缺失值统计：
# company_name             0
# sector                  46
# industry                46
# country                 11
# ticker                  32
# website                 41
# ISIN                   198
# Number of employees     59
# source                  16
# lookup_status            0
# dtype: int64

# %% [markdown]
# # open figi

# %%
import os
import pandas as pd
import requests
from dotenv import load_dotenv
from time import sleep
from tqdm import tqdm

# 加载 API Key
load_dotenv()
API_KEY = os.getenv("OPENFIGI_API_KEY")
HEADERS = {
    'Content-Type': 'application/json',
    'X-OPENFIGI-APIKEY': API_KEY
}

# 读取公司列表
company_n = pd.read_csv("company_metadata.csv")

# 查询函数
import requests

def query_figi_by_name(name):
    url = "https://api.openfigi.com/v3/search"
    payload = {"query": name}
    try:
        response = requests.post(url, headers=HEADERS, json=payload)
        if response.status_code == 200:
            data = response.json()
            results = data.get("data", [])
            if results:
                first_result = results[0]
                ticker = first_result.get("ticker", "")
                composite_figi = first_result.get("compositeFIGI", "")

                # 尝试获取真正的 ISIN
                isin = ""
                security_identifiers = first_result.get("securityIdentifiers", [])
                for ident in security_identifiers:
                    if ident.get("idType") == "ID_ISIN":
                        isin = ident.get("identifier", "")
                        break

                return ticker, composite_figi, isin
        return "", "", ""
    except Exception as e:
        print(f"Error querying {name}: {e}")
        return "", "", ""


# 批量查找并加进度条
tickers, figis, isins = [], [], []

print("⏳ 正在查找公司 Ticker、FIGI 和 ISIN ...")
for name in tqdm(company_n['company_name'], desc="Querying OpenFIGI"):
    ticker, figi, isin = query_figi_by_name(name)
    tickers.append(ticker)
    figis.append(figi)
    isins.append(isin)
    sleep(0.7)  # 控制请求频率，避免被限流

# 写入结果
company_n['ticker'] = tickers
company_n['figi'] = figis
company_n['isin'] = isins
company_n['lookup_status'] = ['done' if t or i else 'not found' for t, i in zip(tickers, isins)]
# Out:
# ⏳ 正在查找公司 Ticker、FIGI 和 ISIN ...
# Querying OpenFIGI: 100%|██████████| 198/198 [03:34<00:00,  1.08s/it]

# %%
# 保存结果
company_n.to_csv("company_list_filled.csv", index=True)

# 缺失值统计（统一为小写列名）
missing_ticker = (company_n['ticker'].astype(str).str.strip() == "").sum()
missing_figi   = (company_n['figi'].astype(str).str.strip() == "").sum()
missing_isin   = (company_n['isin'].astype(str).str.strip() == "").sum()

# 输出结果
print(f"\n✅ 查找完成，统计如下：")
print(f" - 缺失 Ticker 的公司数：{missing_ticker}")
print(f" - 缺失 FIGI 的公司数：{missing_figi}")
print(f" - 缺失 ISIN 的公司数：{missing_isin}")
print(f" - 总公司数：{len(company_n)}")
# Out:
# ✅ 查找完成，统计如下：
#  - 缺失 Ticker 的公司数：130
#  - 缺失 FIGI 的公司数：130
#  - 缺失 ISIN 的公司数：198
#  - 总公司数：198

# %%
import os
import pandas as pd
import requests
from dotenv import load_dotenv
from time import sleep
from tqdm import tqdm

# 加载 API Key
load_dotenv()
API_KEY = os.getenv("OPENFIGI_API_KEY")
HEADERS = {
    'Content-Type': 'application/json',
    'X-OPENFIGI-APIKEY': API_KEY
}

# 只读取公司名列（防止加载多余列）
company_list = pd.read_csv("company_metadata.csv", usecols=["company_name"])

# 查询函数
def query_figi_by_name(name):
    url = "https://api.openfigi.com/v3/search"
    payload = {"query": name}
    try:
        response = requests.post(url, headers=HEADERS, json=payload)
        if response.status_code == 200:
            data = response.json()
            results = data.get("data", [])
            if results:
                first_result = results[0]
                ticker = first_result.get("ticker", "")
                composite_figi = first_result.get("compositeFIGI", "")

                # 获取 ISIN
                isin = ""
                security_identifiers = first_result.get("securityIdentifiers", [])
                for ident in security_identifiers:
                    if ident.get("idType") == "ID_ISIN":
                        isin = ident.get("identifier", "")
                        break

                return ticker, composite_figi, isin
        return "", "", ""
    except Exception as e:
        print(f"Error querying {name}: {e}")
        return "", "", ""

# 批量查找
tickers, figis, isins = [], [], []

print("⏳ 正在查找公司 Ticker、FIGI 和 ISIN ...")
for name in tqdm(company_list['company_name'], desc="Querying OpenFIGI"):
    ticker, figi, isin = query_figi_by_name(name)
    tickers.append(ticker)
    figis.append(figi)
    isins.append(isin)
    sleep(0.7)

# 构造新 DataFrame
result_df = pd.DataFrame({
    "company_name": company_list['company_name'],
    "ticker": tickers,
    "figi": figis,
    "isin": isins
})
# Out:
# ⏳ 正在查找公司 Ticker、FIGI 和 ISIN ...
# Querying OpenFIGI: 100%|██████████| 198/198 [03:30<00:00,  1.06s/it]

# %%
# 保存结果
result_df.to_csv("company_figi_result.csv", index=True)

# 缺失值统计
missing_ticker = (result_df['ticker'].astype(str).str.strip() == "").sum()
missing_figi = (result_df['figi'].astype(str).str.strip() == "").sum()
missing_isin = (result_df['isin'].astype(str).str.strip() == "").sum()

print(f"\n✅ 查找完成，统计如下：")
print(f" - 缺失 Ticker 的公司数：{missing_ticker}")
print(f" - 缺失 FIGI 的公司数：{missing_figi}")
print(f" - 缺失 ISIN 的公司数：{missing_isin}")
print(f" - 总公司数：{len(result_df)}")
# Out:
# ✅ 查找完成，统计如下：
#  - 缺失 Ticker 的公司数：128
#  - 缺失 FIGI 的公司数：128
#  - 缺失 ISIN 的公司数：198
#  - 总公司数：198

# %%
import pandas as pd

# 读取两个文件
figi_df = pd.read_csv("company_figi_result.csv")
yahoo_df = pd.read_csv("company_metadata.csv")

# 只保留公司名和 ticker 列
figi_df = figi_df[["company_name", "ticker"]].rename(columns={"ticker": "figi_ticker"})
yahoo_df = yahoo_df[["company_name", "ticker"]].rename(columns={"ticker": "yahoo_ticker"})

# 合并两个来源的数据
merged = pd.merge(figi_df, yahoo_df, on="company_name", how="outer")

# 比较是否一致
merged["ticker_match"] = merged["figi_ticker"].fillna("").str.strip().str.upper() == \
                         merged["yahoo_ticker"].fillna("").str.strip().str.upper()

# 显示冲突项（不一致且两个都不为空）
conflicts = merged[
    (~merged["ticker_match"]) &
    (merged["figi_ticker"].notna()) & (merged["figi_ticker"].astype(str).str.strip() != "") &
    (merged["yahoo_ticker"].notna()) & (merged["yahoo_ticker"].astype(str).str.strip() != "")
]

# 输出冲突结果
print(f"\n🔍 发现 ticker 冲突的公司数：{len(conflicts)}")
print(conflicts[["company_name", "figi_ticker", "yahoo_ticker"]].head())

# 也可以保存冲突表
conflicts.to_csv("ticker_conflicts.csv", index=False)
# Out:
# 🔍 发现 ticker 冲突的公司数：61
#         company_name                figi_ticker yahoo_ticker
# 0             1&1 AG                        DRI         SB=F
# 1       3I Group PLC  IIILN 6.875 03/09/23 EMTN        TGOPY
# 2  AIA Group Limited                      13469       7A20.F
# 3          AT&T Corp        T 7.3 11/15/11 REGS            T
# 4           AT&T Inc             T 5.1 09/15/14            T

# %% [markdown]
# # Financial Table

# %% [markdown]
# # use CIK to search in SEC EDGAR

# %%
import pandas as pd
import json
from difflib import get_close_matches

# 1. 加载 SEC 提供的 Ticker→CIK 数据
with open("/Users/lori/IRP/company_tickers.json", 'r') as f:
    sec_data = json.load(f)

# 2. 整理成 DataFrame（键是 CIK）
sec_records = []
for cik_str, info in sec_data.items():
    sec_records.append({
        'cik': str(cik_str).zfill(10),
        'ticker': info.get('ticker', '').upper(),
        'sec_name': info.get('title', '').strip().lower()
    })

sec_df = pd.DataFrame(sec_records)

# 3. 读取你的公司元数据 CSV（替换成你用的那个）
your_df = pd.read_csv("company_metadata.csv")
your_df['ticker'] = your_df['ticker'].astype(str).str.upper()
your_df['company_name'] = your_df['company_name'].astype(str).str.lower()

# 4. 通过 ticker 匹配
merged_df = pd.merge(
    your_df, sec_df,
    how='left',
    on='ticker'
)

# 5. 如果没有通过 ticker 匹配，再尝试公司名模糊匹配
for idx, row in merged_df[merged_df['cik'].isna()].iterrows():
    name = row['company_name']
    match = get_close_matches(name, sec_df['sec_name'], n=1, cutoff=0.85)
    if match:
        matched_row = sec_df[sec_df['sec_name'] == match[0]].iloc[0]
        merged_df.at[idx, 'cik'] = matched_row['cik']

# 6. 提取需要的列
final_df = merged_df[['company_name', 'ticker', 'cik']]

# %%
# 7. 保存为新文件
output_path = "company_with_cik.csv"
final_df.to_csv(output_path, index=False)
print(f" finished: CIK saved to {output_path}")

# 8. 统计匹配情况
missing = final_df['cik'].isna().sum()
print(f"🔍 no. of missing CIK :{missing} / {len(final_df)}")
# Out:
#  finished: CIK saved to company_with_cik.csv
# 🔍 no. of missing CIK :103 / 198

# %% [markdown]
# below are 2021-2025 data

# %% [markdown]
# ticker，year，total revenue,source

# %%
import pandas as pd
import yfinance as yf
import time

# 读取公司表
df_meta = pd.read_csv("company_metadata.csv")

# 创建空列表保存结果
revenue_data = []

# 遍历每个 ticker
for i, row in df_meta.iterrows():
    ticker = row.get("ticker")
    company_id = row.get("company_id")

    if pd.isna(ticker):
        continue  # 没有 ticker 的跳过

    try:
        yf_ticker = yf.Ticker(ticker)
        financials = yf_ticker.financials.T  # 年份为行，指标为列
        financials.reset_index(inplace=True)
        financials.rename(columns={"index": "Fiscal Year"}, inplace=True)

        for _, fin_row in financials.iterrows():
            fiscal_year = str(fin_row["Fiscal Year"])[:4]
            revenue = fin_row.get("Total Revenue")
            if pd.notna(revenue):
                revenue_data.append({
                    "company_id": company_id,
                    "ticker": ticker,
                    "fiscal_year": fiscal_year,
                    "total_revenue": revenue,
                    "source": "yfinance"
                })

        print(f"{i+1}/{len(df_meta)}: {ticker} ✓")
        time.sleep(0.5)  # 控速防止被封 IP
    except Exception as e:
        print(f"{i+1}/{len(df_meta)}: {ticker} ❌ Error: {e}")

# 转为 DataFrame
df_revenue = pd.DataFrame(revenue_data)

# 保存为 CSV
df_revenue.to_csv("company_revenue_yfinance.csv", index=False)
# Out:
# 1/198: SB=F ✓
# 2/198: TGOPY ✓
# 3/198: AGOAF ✓
# 4/198: 7A20.F ✓
# 5/198: AC.TO ✓
# 6/198: AIXAD.XC ✓
# 7/198: FKM.F ✓
# 8/198: AKSO.OL ✓
# 9/198: AMUN.VI ✓
# 10/198: FG1.F ✓
# 11/198: FG1.F ✓
# 12/198: ARRD.HM ✓
# 13/198: ARRD.HM ✓
# 14/198: 0RUH.IL ✓
# 15/198: AZN ✓
# 16/198: MKL.F ✓
# 17/198: AEXAD ✓
# 18/198: T ✓
# 19/198: T ✓
# 20/198: QRL.F ✓
# 21/198: AV.L ✓
# 22/198: SAN ✓
# 23/198: BSBR ✓
# 24/198: 7832.T ✓
# 25/198: ABR.BE ✓
# 26/198: BCE.TO ✓
# 27/198: BCHEY ✓
# 28/198: BTG4.F ✓
# 29/198: BTG4.F ✓
# 34/198: BSX ✓
# 35/198: R1H.F ✓
# 36/198: BUHA.F ✓
# 37/198: SKVB.F ✓
# 38/198: CTYA.F ✓
# 39/198: CPCAF ✓
# 40/198: CWC.F ✓
# 41/198: CGF.AX ✓
# 42/198: GK9.F ✓
# 43/198: CVX ✓
# 44/198: CVX ✓
# 45/198: 2610.TW ✓
# 46/198: CGMBF ✓
# 48/198: C ✓
# 50/198: CBH.F ✓
# 51/198: CBHD.SG ✓
# 52/198: ED ✓
# 53/198: FCG.NZ ✓
# 54/198: 9FM.F ✓
# 55/198: CRH ✓
# 56/198: CRH ✓
# 57/198: 6CMB.F ✓
# 58/198: 6CMB.F ✓
# 59/198: CMW.AX ✓
# 63/198: DLN.F ✓
# 64/198: DB ✓
# 65/198: DTEGY ✓
# 66/198: DEO ✓
# 67/198: DEO ✓
# 68/198: DS5.F ✓
# 69/198: GIL.VI ✓
# 70/198: D ✓
# 71/198: D ✓
# 72/198: KABN.F ✓
# 73/198: DNE.F ✓
# 74/198: E ✓
# 75/198: EOAN.DE ✓
# 77/198: FOIBS.XD ✓
# 78/198: RACE ✓
# 79/198: FCC.MC ✓
# 80/198: FCC.MC ✓
# 81/198: F ✓
# 82/198: FRAS.F ✓
# 83/198: GLEN.L ✓
# 85/198: HEI.MU ✓
# 86/198: 4QT1.F ✓
# 87/198: HK2C.SG ✓
# 89/198: HRZA.F ✓
# 92/198: ILKAY ✓
# 93/198: IFX.DE ✓
# 94/198: IEA.F ✓
# 95/198: INFY ✓
# 96/198: IPXHY ✓
# 97/198: 8IF1.F ✓
# 98/198: IBM ✓
# 99/198: IBM ✓
# 100/198: ISP.MI ✓
# 101/198: ITRI ✓
# 102/198: JPM ✓
# 103/198: JPM ✓
# 104/198: KAOOY ✓
# 105/198: 0GTO.L ✓
# 106/198: KBXA.F ✓
# 107/198: KBXA.F ✓
# 108/198: KNEBV.HE ✓
# 109/198: KNEBV.HE ✓
# 110/198: KOP ✓
# 112/198: KOS ✓
# 113/198: KHNGY ✓
# 114/198: 0K1.F ✓
# 115/198: LANDZ.XC ✓
# 116/198: LEA ✓
# 117/198: DRS ✓
# 118/198: FMNB.F ✓
# 119/198: LMT ✓
# 120/198: 1RY.F ✓
# 121/198: LYB ✓
# 122/198: NMSCA ✓
# 123/198: MAPE.XC ✓
# 124/198: MFI.TO ✓
# 126/198: MGROS.IS ✓
# 127/198: MIH.F ✓
# 128/198: MTSFY ✓
# 130/198: 74S.F ✓
# 131/198: NAL.F ✓
# 132/198: NESM.MU ✓
# 134/198: 7731.T ✓
# 135/198: NDX1.F ✓
# 136/198: ORI1.F ✓
# 139/198: PVH ✓
# 140/198: RMY.F ✓
# 141/198: REP.MC ✓
# 142/198: ROI.DE ✓
# 143/198: RY.TO ✓
# 144/198: RSL2.F ✓
# 145/198: 0OFU.IL ✓
# 146/198: SLB ✓
# 147/198: SLB ✓
# 148/198: HSWYX ✓
# 149/198: PYXB.F ✓
# 150/198: PYXB.F ✓
# 151/198: SENEA ✓
# 154/198: 08HH.F ✓
# 155/198: 08HH.F ✓
# 156/198: SBSW ✓
# 157/198: C6L.SI ✓
# 158/198: AOS ✓
# 159/198: AOS ✓
# 160/198: 9984.T ✓
# 161/198: 9984.T ✓
# 162/198: SONY ✓
# 163/198: LUV ✓
# 164/198: STN.TO ✓
# 165/198: STN.TO ✓
# 166/198: SU.TO ✓
# 168/198: SUNPHARMA.NS ✓
# 169/198: SW9.F ✓
# 170/198: 1979.T ✓
# 171/198: TN2.F ✓
# 172/198: TN2.F ✓
# 173/198: T5R.F ✓
# 174/198: GGAL ✓
# 175/198: TEL.OL ✓
# 178/198: TS ✓
# 179/198: TM ✓
# 180/198: TUI1.DE ✓
# 184/198: CVLB.SG ✓
# 185/198: VALE ✓
# 186/198: VALE ✓
# 187/198: VIB3.F ✓
# 188/198: V ✓
# 189/198: V ✓
# 190/198: VOD ✓
# 192/198: US9802283088.SG ✓
# 193/198: 0P0001CO7N ✓
# 196/198: WO60.F ✓
# 197/198: IU2.F ✓

# %% [markdown]
# 有ticker,财年，total revenue, net income,net income margin,r&d,total liability, long term debt,cash, capex,source

# %%
import pandas as pd
import yfinance as yf
import time

# 读取公司表
df_meta = pd.read_csv("company_metadata.csv")

# 创建空列表保存结果
revenue_data = []

for i, row in df_meta.iterrows():
    ticker = row.get("ticker")
    company_id = row.get("company_id")

    if pd.isna(ticker):
        continue  # 没有 ticker 的跳过

    try:
        yf_ticker = yf.Ticker(ticker)

        # 提取利润表、资产负债表、现金流量表
        financials = yf_ticker.financials.T
        balance_sheet = yf_ticker.balance_sheet.T
        cashflow = yf_ticker.cashflow.T

        # 重命名时间列
        financials.reset_index(inplace=True)
        balance_sheet.reset_index(inplace=True)
        cashflow.reset_index(inplace=True)
        financials.rename(columns={"index": "Fiscal Year"}, inplace=True)
        balance_sheet.rename(columns={"index": "Fiscal Year"}, inplace=True)
        cashflow.rename(columns={"index": "Fiscal Year"}, inplace=True)

        for _, fin_row in financials.iterrows():
            fiscal_year = str(fin_row["Fiscal Year"])[:4]

            revenue = fin_row.get("Total Revenue")
            net_income = fin_row.get("Net Income")
            r_and_d = fin_row.get("Research Development")

            # 派生字段：利润率
            net_income_margin = net_income / revenue if pd.notna(revenue) and revenue != 0 else None

            # 对应年份资产负债表数据
            bs_row = balance_sheet[balance_sheet["Fiscal Year"].astype(str).str.startswith(fiscal_year)]
            total_liabilities = long_term_debt = cash = None
            if not bs_row.empty:
                bs = bs_row.iloc[0]
                total_liabilities = bs.get("Total Liab")
                long_term_debt = bs.get("Long Term Debt")
                cash = bs.get("Cash And Cash Equivalents")

            # 对应年份现金流数据
            cf_row = cashflow[cashflow["Fiscal Year"].astype(str).str.startswith(fiscal_year)]
            capex = None
            if not cf_row.empty:
                capex = cf_row.iloc[0].get("Capital Expenditures")

            # 添加数据
            if pd.notna(revenue):
                revenue_data.append({
                    "company_id": company_id,
                    "ticker": ticker,
                    "fiscal_year": fiscal_year,
                    "total_revenue": revenue,
                    "net_income": net_income,
                    "net_income_margin": net_income_margin,
                    "r_and_d": r_and_d,
                    "total_liabilities": total_liabilities,
                    "long_term_debt": long_term_debt,
                    "cash_and_cash_equivalents": cash,
                    "capex": capex,
                    "source": "yfinance"
                })

        print(f"{i+1}/{len(df_meta)}: {ticker} ✓")
        time.sleep(0.5)

    except Exception as e:
        print(f"{i+1}/{len(df_meta)}: {ticker} ❌ Error: {e}")

# 转为 DataFrame
df_revenue = pd.DataFrame(revenue_data)

# 保存为 CSV
df_revenue.to_csv("company_revenue_extended.csv", index=False)
# Out:
# 1/198: SB=F ✓
# 2/198: TGOPY ✓
# 3/198: AGOAF ✓
# 4/198: 7A20.F ✓
# 5/198: AC.TO ✓
# 6/198: AIXAD.XC ✓
# 7/198: FKM.F ✓
# 8/198: AKSO.OL ✓
# 9/198: AMUN.VI ✓
# 10/198: FG1.F ✓
# 11/198: FG1.F ✓
# 12/198: ARRD.HM ✓
# 13/198: ARRD.HM ✓
# 14/198: 0RUH.IL ✓
# 15/198: AZN ✓
# 16/198: MKL.F ✓
# 17/198: AEXAD ✓
# 18/198: T ✓
# 19/198: T ✓
# 20/198: QRL.F ✓
# 21/198: AV.L ✓
# 22/198: SAN ✓
# 23/198: BSBR ✓
# 24/198: 7832.T ✓
# 25/198: ABR.BE ✓
# 26/198: BCE.TO ✓
# 27/198: BCHEY ✓
# 28/198: BTG4.F ✓
# 29/198: BTG4.F ✓
# 34/198: BSX ✓
# 35/198: R1H.F ✓
# 36/198: BUHA.F ✓
# 37/198: SKVB.F ✓
# 38/198: CTYA.F ✓
# 39/198: CPCAF ✓
# 40/198: CWC.F ✓
# 41/198: CGF.AX ✓
# 42/198: GK9.F ✓
# 43/198: CVX ✓
# 44/198: CVX ✓
# 45/198: 2610.TW ✓
# 46/198: CGMBF ✓
# 48/198: C ✓
# 50/198: CBH.F ✓
# 51/198: CBHD.SG ✓
# 52/198: ED ✓
# 53/198: FCG.NZ ✓
# 54/198: 9FM.F ✓
# 55/198: CRH ✓
# 56/198: CRH ✓
# 57/198: 6CMB.F ✓
# 58/198: 6CMB.F ✓
# 59/198: CMW.AX ✓
# 63/198: DLN.F ✓
# 64/198: DB ✓
# 65/198: DTEGY ✓
# 66/198: DEO ✓
# 67/198: DEO ✓
# 68/198: DS5.F ✓
# 69/198: GIL.VI ✓
# 70/198: D ✓
# 71/198: D ✓
# 72/198: KABN.F ✓
# 73/198: DNE.F ✓
# 74/198: E ✓
# 75/198: EOAN.DE ✓
# 77/198: FOIBS.XD ✓
# 78/198: RACE ✓
# 79/198: FCC.MC ✓
# 80/198: FCC.MC ✓
# 81/198: F ✓
# 82/198: FRAS.F ✓
# 83/198: GLEN.L ✓
# 85/198: HEI.MU ✓
# 86/198: 4QT1.F ✓
# 87/198: HK2C.SG ✓
# 89/198: HRZA.F ✓
# 92/198: ILKAY ✓
# 93/198: IFX.DE ✓
# 94/198: IEA.F ✓
# 95/198: INFY ✓
# 96/198: IPXHY ✓
# 97/198: 8IF1.F ✓
# 98/198: IBM ✓
# 99/198: IBM ✓
# 100/198: ISP.MI ✓
# 101/198: ITRI ✓
# 102/198: JPM ✓
# 103/198: JPM ✓
# 104/198: KAOOY ✓
# 105/198: 0GTO.L ✓
# 106/198: KBXA.F ✓
# 107/198: KBXA.F ✓
# 108/198: KNEBV.HE ✓
# 109/198: KNEBV.HE ✓
# 110/198: KOP ✓
# 112/198: KOS ✓
# 113/198: KHNGY ✓
# 114/198: 0K1.F ✓
# 115/198: LANDZ.XC ✓
# 116/198: LEA ✓
# 117/198: DRS ✓
# 118/198: FMNB.F ✓
# 119/198: LMT ✓
# 120/198: 1RY.F ✓
# 121/198: LYB ✓
# 122/198: NMSCA ✓
# 123/198: MAPE.XC ✓
# 124/198: MFI.TO ✓
# 126/198: MGROS.IS ✓
# 127/198: MIH.F ✓
# 128/198: MTSFY ✓
# 130/198: 74S.F ✓
# 131/198: NAL.F ✓
# 132/198: NESM.MU ✓
# 134/198: 7731.T ✓
# 135/198: NDX1.F ✓
# 136/198: ORI1.F ✓
# 139/198: PVH ✓
# 140/198: RMY.F ✓
# 141/198: REP.MC ✓
# 142/198: ROI.DE ✓
# 143/198: RY.TO ✓
# 144/198: RSL2.F ✓
# 145/198: 0OFU.IL ✓
# 146/198: SLB ✓
# 147/198: SLB ✓
# 148/198: HSWYX ✓
# 149/198: PYXB.F ✓
# 150/198: PYXB.F ✓
# 151/198: SENEA ✓
# 154/198: 08HH.F ✓
# 155/198: 08HH.F ✓
# 156/198: SBSW ✓
# 157/198: C6L.SI ✓
# 158/198: AOS ✓
# 159/198: AOS ✓
# 160/198: 9984.T ✓
# 161/198: 9984.T ✓
# 162/198: SONY ✓
# 163/198: LUV ✓
# 164/198: STN.TO ✓
# 165/198: STN.TO ✓
# 166/198: SU.TO ✓
# 168/198: SUNPHARMA.NS ✓
# 169/198: SW9.F ✓
# 170/198: 1979.T ✓
# 171/198: TN2.F ✓
# 172/198: TN2.F ✓
# 173/198: T5R.F ✓
# 174/198: GGAL ✓
# 175/198: TEL.OL ✓
# 178/198: TS ✓
# 179/198: TM ✓
# 180/198: TUI1.DE ✓
# 184/198: CVLB.SG ✓
# 185/198: VALE ✓
# 186/198: VALE ✓
# 187/198: VIB3.F ✓
# 188/198: V ✓
# 189/198: V ✓
# 190/198: VOD ✓
# 192/198: US9802283088.SG ✓
# 193/198: 0P0001CO7N ✓
# 196/198: WO60.F ✓
# 197/198: IU2.F ✓

# %% [markdown]
# There is no data below, the table is empty, and 2017-2019 does not seem to be available from yfiannce

# %%
import pandas as pd
import yfinance as yf
import time

# 读取公司表
df_meta = pd.read_csv("company_metadata.csv")

# 创建空列表保存结果
revenue_data = []

# 遍历每个 ticker
for i, row in df_meta.iterrows():
    ticker = row.get("ticker")
    company_id = row.get("company_id")

    if pd.isna(ticker):
        continue  # 没有 ticker 的跳过

    try:
        yf_ticker = yf.Ticker(ticker)
        financials = yf_ticker.financials.T  # 年份为行，指标为列
        financials.reset_index(inplace=True)
        financials.rename(columns={"index": "Fiscal Year"}, inplace=True)

        for _, fin_row in financials.iterrows():
            fiscal_year = str(fin_row["Fiscal Year"])[:4]
            if fiscal_year not in ['2017', '2018', '2019']:
                continue
            revenue = fin_row.get("Total Revenue")
            if pd.notna(revenue):
                revenue_data.append({
                    "company_id": company_id,
                    "ticker": ticker,
                    "fiscal_year": fiscal_year,
                    "total_revenue": revenue,
                    "source": "yfinance"
                })

        print(f"{i+1}/{len(df_meta)}: {ticker} ✓")
        time.sleep(0.5)  # 控速防止被封 IP
    except Exception as e:
        print(f"{i+1}/{len(df_meta)}: {ticker}  Error: {e}")

# 转为 DataFrame
df_revenue = pd.DataFrame(revenue_data)

# 保存为 CSV
df_revenue.to_csv("company_revenue.csv", index=False)
# Out:
# 1/198: SB=F ✓
# 2/198: TGOPY ✓
# 3/198: AGOAF ✓
# 4/198: 7A20.F ✓
# 5/198: AC.TO ✓
# 6/198: AIXAD.XC ✓
# 7/198: FKM.F ✓
# 8/198: AKSO.OL ✓
# 9/198: AMUN.VI ✓
# 10/198: FG1.F ✓
# 11/198: FG1.F ✓
# 12/198: ARRD.HM ✓
# 13/198: ARRD.HM ✓
# 14/198: 0RUH.IL ✓
# 15/198: AZN ✓
# 16/198: MKL.F ✓
# 17/198: AEXAD ✓
# 18/198: T ✓
# 19/198: T ✓
# 20/198: QRL.F ✓
# 21/198: AV.L ✓
# 22/198: SAN ✓
# 23/198: BSBR ✓
# 24/198: 7832.T ✓
# 25/198: ABR.BE ✓
# 26/198: BCE.TO ✓
# 27/198: BCHEY ✓
# 28/198: BTG4.F ✓
# 29/198: BTG4.F ✓
# 34/198: BSX ✓
# 35/198: R1H.F ✓
# 36/198: BUHA.F ✓
# 37/198: SKVB.F ✓
# 38/198: CTYA.F ✓
# 39/198: CPCAF ✓
# 40/198: CWC.F ✓
# 41/198: CGF.AX ✓
# 42/198: GK9.F ✓
# 43/198: CVX ✓
# 44/198: CVX ✓
# 45/198: 2610.TW ✓
# 46/198: CGMBF ✓
# 48/198: C ✓
# 50/198: CBH.F ✓
# 51/198: CBHD.SG ✓
# 52/198: ED ✓
# 53/198: FCG.NZ ✓
# 54/198: 9FM.F ✓
# 55/198: CRH ✓
# 56/198: CRH ✓
# 57/198: 6CMB.F ✓
# 58/198: 6CMB.F ✓
# 59/198: CMW.AX ✓
# 63/198: DLN.F ✓
# 64/198: DB ✓
# 65/198: DTEGY ✓
# 66/198: DEO ✓
# 67/198: DEO ✓
# 68/198: DS5.F ✓
# 69/198: GIL.VI ✓
# 70/198: D ✓
# 71/198: D ✓
# 72/198: KABN.F ✓
# 73/198: DNE.F ✓
# 74/198: E ✓
# 75/198: EOAN.DE ✓
# 77/198: FOIBS.XD ✓
# 78/198: RACE ✓
# 79/198: FCC.MC ✓
# 80/198: FCC.MC ✓
# 81/198: F ✓
# 82/198: FRAS.F ✓
# 83/198: GLEN.L ✓
# 85/198: HEI.MU ✓
# 86/198: 4QT1.F ✓
# 87/198: HK2C.SG ✓
# 89/198: HRZA.F ✓
# 92/198: ILKAY ✓
# 93/198: IFX.DE ✓
# 94/198: IEA.F ✓
# 95/198: INFY ✓
# 96/198: IPXHY ✓
# 97/198: 8IF1.F ✓
# 98/198: IBM ✓
# 99/198: IBM ✓
# 100/198: ISP.MI ✓
# 101/198: ITRI ✓
# 102/198: JPM ✓
# 103/198: JPM ✓
# 104/198: KAOOY ✓
# 105/198: 0GTO.L ✓
# 106/198: KBXA.F ✓
# 107/198: KBXA.F ✓
# 108/198: KNEBV.HE ✓
# 109/198: KNEBV.HE ✓
# 110/198: KOP ✓
# 112/198: KOS ✓
# 113/198: KHNGY ✓
# 114/198: 0K1.F ✓
# 115/198: LANDZ.XC ✓
# 116/198: LEA ✓
# 117/198: DRS ✓
# 118/198: FMNB.F ✓
# 119/198: LMT ✓
# 120/198: 1RY.F ✓
# 121/198: LYB ✓
# 122/198: NMSCA ✓
# 123/198: MAPE.XC ✓
# 124/198: MFI.TO ✓
# 126/198: MGROS.IS ✓
# 127/198: MIH.F ✓
# 128/198: MTSFY ✓
# 130/198: 74S.F ✓
# 131/198: NAL.F ✓
# 132/198: NESM.MU ✓
# 134/198: 7731.T ✓
# 135/198: NDX1.F ✓
# 136/198: ORI1.F ✓
# 139/198: PVH ✓
# 140/198: RMY.F ✓
# 141/198: REP.MC ✓
# 142/198: ROI.DE ✓
# 143/198: RY.TO ✓
# 144/198: RSL2.F ✓
# 145/198: 0OFU.IL ✓
# 146/198: SLB ✓
# 147/198: SLB ✓
# 148/198: HSWYX ✓
# 149/198: PYXB.F ✓
# 150/198: PYXB.F ✓
# 151/198: SENEA ✓
# 154/198: 08HH.F ✓
# 155/198: 08HH.F ✓
# 156/198: SBSW ✓
# 157/198: C6L.SI ✓
# 158/198: AOS ✓
# 159/198: AOS ✓
# 160/198: 9984.T ✓
# 161/198: 9984.T ✓
# 162/198: SONY ✓
# 163/198: LUV ✓
# 164/198: STN.TO ✓
# 165/198: STN.TO ✓
# 166/198: SU.TO ✓
# 168/198: SUNPHARMA.NS ✓
# 169/198: SW9.F ✓
# 170/198: 1979.T ✓
# 171/198: TN2.F ✓
# 172/198: TN2.F ✓
# 173/198: T5R.F ✓
# 174/198: GGAL ✓
# 175/198: TEL.OL ✓
# 178/198: TS ✓
# 179/198: TM ✓
# 180/198: TUI1.DE ✓
# 184/198: CVLB.SG ✓
# 185/198: VALE ✓
# 186/198: VALE ✓
# 187/198: VIB3.F ✓
# 188/198: V ✓
# 189/198: V ✓
# 190/198: VOD ✓
# 192/198: US9802283088.SG ✓
# 193/198: 0P0001CO7N ✓
# 196/198: WO60.F ✓
# 197/198: IU2.F ✓

# %%
import yfinance as yf

ticker = yf.Ticker("AAPL")  # 替换为你感兴趣的 ticker
financials = ticker.financials.T
print(financials.index)  # 打印所有“Fiscal Year”
# Out:
# DatetimeIndex(['2024-09-30', '2023-09-30', '2022-09-30', '2021-09-30',
#                '2020-09-30'],
#               dtype='datetime64[ns]', freq=None)

# %%
ticker = yf.Ticker("AAPL")
income_stmt = ticker.income_stmt.T
print(income_stmt)
# Out:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 2024-09-30                         0.0              0.241    134661000000.0
# 2023-09-30                         0.0              0.147    125820000000.0
# 2022-09-30                         0.0              0.162    130541000000.0
# 2021-09-30                         0.0              0.133    123136000000.0
# 2020-09-30                         NaN                NaN               NaN
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2024-09-30                                      93736000000.0
# 2023-09-30                                      96995000000.0
# 2022-09-30                                      99803000000.0
# 2021-09-30                                      94680000000.0
# 2020-09-30                                                NaN
#
#            Reconciled Depreciation Reconciled Cost Of Revenue          EBITDA  \
# 2024-09-30           11445000000.0             210352000000.0  134661000000.0
# 2023-09-30           11519000000.0             214137000000.0  125820000000.0
# 2022-09-30           11104000000.0             223546000000.0  130541000000.0
# 2021-09-30           11284000000.0             212981000000.0  123136000000.0
# 2020-09-30                     NaN                        NaN             NaN
#
#                       EBIT Net Interest Income Interest Expense  ...  \
# 2024-09-30  123216000000.0                 NaN              NaN  ...
# 2023-09-30  114301000000.0        -183000000.0     3933000000.0  ...
# 2022-09-30  119437000000.0        -106000000.0     2931000000.0  ...
# 2021-09-30  111852000000.0         198000000.0     2645000000.0  ...
# 2020-09-30             NaN         890000000.0     2873000000.0  ...
#
#            Interest Expense Non Operating Interest Income Non Operating  \
# 2024-09-30                            NaN                           NaN
# 2023-09-30                   3933000000.0                  3750000000.0
# 2022-09-30                   2931000000.0                  2825000000.0
# 2021-09-30                   2645000000.0                  2843000000.0
# 2020-09-30                   2873000000.0                  3763000000.0
#
#            Operating Income Operating Expense Research And Development  \
# 2024-09-30   123216000000.0     57467000000.0            31370000000.0
# 2023-09-30   114301000000.0     54847000000.0            29915000000.0
# 2022-09-30   119437000000.0     51345000000.0            26251000000.0
# 2021-09-30   108949000000.0     43887000000.0            21914000000.0
# 2020-09-30              NaN               NaN                      NaN
#
#            Selling General And Administration    Gross Profit Cost Of Revenue  \
# 2024-09-30                      26097000000.0  180683000000.0  210352000000.0
# 2023-09-30                      24932000000.0  169148000000.0  214137000000.0
# 2022-09-30                      25094000000.0  170782000000.0  223546000000.0
# 2021-09-30                      21973000000.0  152836000000.0  212981000000.0
# 2020-09-30                                NaN             NaN             NaN
#
#              Total Revenue Operating Revenue
# 2024-09-30  391035000000.0    391035000000.0
# 2023-09-30  383285000000.0    383285000000.0
# 2022-09-30  394328000000.0    394328000000.0
# 2021-09-30  365817000000.0    365817000000.0
# 2020-09-30             NaN               NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# # L

# %%
# 读取 parquet 文件
df1 = pd.read_parquet("../OneDrive_1_2025-6-9/compustat_metadata.parquet")


# 显示前几行
print(df1.head())
# Out:
#     gvkey            ISIN      SEDOL        cik        cusip  \
# 0  315022  [KR7104540000]  [B94CCB9]         []           []
# 1  317960  [KYG887641085]  [BNLPLJ0]         []           []
# 2    8085              []         []    [53495]  [675734107]
# 3  309887  [INE122M01019]  [B4JYZ27]         []           []
# 4   29399              []         []  [1655099]  [112830104]
#
#                                                conml            GICS_level_1  \
# 0                                  [CORENTEC CO LTD]             Health Care
# 1                        [TIAN GE INTERACTIVE HLDGS]  Communication Services
# 2                   [October Oil Co, OCTOBER OIL CO]                    None
# 3                               [ESSAR SHIPPING LTD]                  Energy
# 4  [Brookfield Real Assets Income Fund Inc, BROOK...                    None
#
#                        GICS_level_2                      GICS_level_3  loc  \
# 0  Health Care Equipment & Services  Health Care Equipment & Supplies  KOR
# 1             Media & Entertainment      Interactive Media & Services  CHN
# 2                              None                              None  USA
# 3                            Energy       Oil, Gas & Consumable Fuels  IND
# 4                              None                              None  USA
#
#                             weburl curcd  exchg
# 0                             None   KRW  298.0
# 1                             None   CNY  170.0
# 2                             None   USD   13.0
# 3                             None   INR  219.0
# 4  publicsecurities.brookfield.com   USD   11.0

# %%
import pandas as pd
import numpy as np
import ast

def extract_first_isin(x):
    # 先判断空值（仅适用于标量，不是数组）
    if isinstance(x, str):
        x = x.strip()
        if x == "":
            return None
        try:
            x_eval = ast.literal_eval(x)
            if isinstance(x_eval, (list, np.ndarray)) and len(x_eval) > 0:
                return x_eval[0]
        except:
            return None

    elif isinstance(x, (list, np.ndarray)):
        if len(x) == 0:
            return None
        return x[0]

    elif pd.isna(x):
        return None

    return None

# %%
df1["ISIN_cleaned"] = df1["ISIN"].apply(extract_first_isin)

# 统计
total = len(df1)
non_missing = df1["ISIN_cleaned"].notna().sum()
missing = df1["ISIN_cleaned"].isna().sum()

print(f"Total rows: {total}")
print(f"With ISIN: {non_missing}")
print(f"Missing ISIN: {missing}")
print(f"Missing ratio: {missing/total:.2%}")
# Out:
# Total rows: 104680
# With ISIN: 59733
# Missing ISIN: 44947
# Missing ratio: 42.94%

# %%
# 读取 parquet 文件
df = pd.read_parquet("../OneDrive_1_2025-6-9/json_metadata.parquet")


# 显示前几行
print(df.head())
# Out:
#                                       pdf_local_path  \
# 0  /srv/data/mrei/davinci/davinci_data_v11_2022_u...
# 1  /srv/data/mrei/davinci/davinci_data_v11_2022_u...
# 2  /srv/data/mrei/davinci/davinci_data_v11_2022_u...
# 3  /srv/data/mrei/davinci/davinci_data_v11_2022_u...
# 4  /srv/data/mrei/davinci/davinci_data_v11_2022_u...
#
#                              pdf_local_path_relative  \
# 0  000009/Tadano_Ltd_integrated_report2021_en_7_g...
# 1  000009/Tadano_Ltd_integrated_report2022_en_for...
# 2  000009/Taikisha_Ltd_pdf-index-2021-01_7r58ksqc...
# 3  000009/Taikisha_Ltd_pdf-index-2022-02_nllsl2qx...
# 4  000009/Takasago_International_Corp_Takasago20S...
#
#                                               pdfurl pdf_source_path  \
# 0  https://www.tadano.com/upload/docs/integrated_...            None
# 1  https://www.tadano.com/upload/docs/integrated_...            None
# 2  https://www.taikisha-group.com/sustainability/...            None
# 3  https://www.taikisha-group.com/sustainability/...            None
# 4  https://assets.takasago.com/prod/default/s3fs-...            None
#
#          searched_company_name  search_rank         source  \
# 0                   Tadano Ltd            1  google_search
# 1                   Tadano Ltd            3  google_search
# 2                 Taikisha Ltd            3  google_search
# 3                 Taikisha Ltd            1  google_search
# 4  Takasago International Corp            1  google_search
#
#                     md5_fingerprint     time_downloaded pdf_title pdf_author  \
# 0  77bb2990686e1509f8ba790a6a2eeffe  1699496911.4256902                 None
# 1  c8095caf9d14ee73c44de89102380bcb   1699496912.334108      None       None
# 2  ad88313421d39a8afa9e32ed03ee3c75   1699488723.331302      None       None
# 3  217c0a48e25415855343f4f1d9316259   1699489131.509729      None       None
# 4  78c1b3239aee77f27bd9010e8b52e1f2  1699499833.9023306                 None
#
#   pdf_subject        pdf_creation_time predicted_language  \
# 0        None  D:20220114140730+09'00'                 en
# 1        None  D:20221209152016+09'00'                 en
# 2        None  D:20211220191732+09'00'                 en
# 3        None  D:20221210111703+09'00'                 en
# 4        None  D:20220920103340+09'00'                 en
#
#    predicted_report_type       predicted_company_name predicted_report_year  \
# 0  sustainability report                   Tadano Ltd                  2021
# 1  sustainability report                   Tadano Ltd                  2022
# 2      integrated report                 Taikisha Ltd                  2021
# 3      integrated report                 Taikisha Ltd                  2022
# 4  sustainability report  Takasago International Corp                  2021
#
#        time_processed  n_tokenised_sentences  n_predicted_initiatives
# 0  1699498549.3246822                    735                        8
# 1  1699498546.4602056                   2341                        9
# 2  1699489970.6086187                   6464                       11
# 3  1699489970.9746637                   6498                        5
# 4  1699500939.8893101                   3216                       10

# %%
import pandas as pd

# 读取 parquet 文件
df = pd.read_parquet("../OneDrive_1_2025-6-9/lseg_more_metadata.parquet")


# 显示前几行
print(df.head())
# Out:
#    Instrument  TR.MIC TR.ExchangeCode  TR.CompanyMarketCap  \
# 0  LP68841490     NaN             LIP                  NaN
# 1  LP68841491     NaN             LIP                  NaN
# 2  LP68841495     NaN             LIP                  NaN
# 3  LP68841496     NaN             LIP                  NaN
# 4  LP68841497     NaN             LIP                  NaN
#
#                                     TR.CommonName TR.GICSSector  \
# 0  Desjardins Target 2026 Investment Grade Bond C          None
# 1  Desjardins Target 2026 Investment Grade Bond C          None
# 2  Desjardins Target 2027 Investment Grade Bond C          None
# 3  Desjardins Target 2027 Investment Grade Bond C          None
# 4  Desjardins Target 2027 Investment Grade Bond C          None
#
#   TR.GICSIndustryGroup TR.GICSIndustry TR.BusinessSummary TR.AlsoKnownAsName  \
# 0                 None            None               None               None
# 1                 None            None               None               None
# 2                 None            None               None               None
# 3                 None            None               None               None
# 4                 None            None               None               None
#
#   TR.FormerlyKnownAsName TR.DoingBusinessAsName TR.ImmediateParent  \
# 0                   None                   None               None
# 1                   None                   None               None
# 2                   None                   None               None
# 3                   None                   None               None
# 4                   None                   None               None
#
#   TR.UltimateParent
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None

# %%
import pandas as pd

# 读取 parquet 文件
df = pd.read_parquet("../OneDrive_1_2025-6-9/N3u_gpt_without_text.parquet")


# 显示前几行
print(df.head())
# Out:
#                     md5_fingerprint  \
# 0  3014d9f1056be7c44a1a493c806a57f4
# 1  9c74edfc0053e2d55966b14b2b8f719a
# 2  9c74edfc0053e2d55966b14b2b8f719a
# 3  45bc567c0a633a6464c4b0fd820a6127
# 4  8a0c411368909088c724f493fcca1101
#
#                                       pdf_local_path  \
# 0  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
# 1  /srv/data/mrei/davinci/davinci_data_v8_public_...
# 2  /srv/data/mrei/davinci/davinci_data_v11_2022_u...
# 3  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
# 4  /srv/data/mrei/davinci/davinci_data_v6_crawl/p...
#
#                              pdf_local_path_relative  \
# 0  000110/Unknown_financial-economic-review-1998_...
# 1             000033/Unknown_5055330315_u5l5tbnz.pdf
# 2             000033/Unknown_5055330315_ijjv3k4d.pdf
# 3         000014/Unknown_2004-0138-2967_3cfjjajt.pdf
# 4                000149/Unknown_Block-3_c2hw2oxq.pdf
#
#                                               pdfurl pdf_source_path  \
# 0  https://www2.gov.bc.ca/assets/gov/british-colu...            None
# 1  https://www.bseindia.com/bseplus/annualreport/...            None
# 2  https://www.bseindia.com/bseplus/AnnualReport/...            None
# 3  https://www.cdc.gov/niosh/hhe/reports/pdfs/200...            None
# 4  https://www.egyankosh.ac.in/bitstream/12345678...            None
#
#                     searched_company_name  search_rank         source  \
# 0           Imperial Ginseng Products Ltd            3  google_search
# 1  Hardcastle & Waud Manufacturing Co Ltd            3  google_search
# 2  Hardcastle & Waud Manufacturing Co Ltd            3  google_search
# 3                            Staples Inc.            2  google_search
# 4                       Quizam Media Corp            2  google_search
#
#       time_downloaded                                          pdf_title  ...  \
# 0  1663778412.2352734  British Columbia Financial & Economic Review 1998  ...
# 1  1684231121.2920866                                               None  ...
# 2   1701325938.497968                                               None  ...
# 3  1652866167.2012277  HHE Report No. HETA-2004-0138-2967, Samuel Sta...  ...
# 4  1689171372.7663267                                               None  ...
#
#                                               answer      cost  \
# 0  ```json\n{\n    "report_type": "Other",\n    "...  0.000796
# 1  ```json\n{\n    "report_type": "Annual Report"...  0.000572
# 2  ```json\n{\n    "report_type": "Annual Report"...  0.000572
# 3  ```json\n{\n    "report_type": "Other",\n    "...  0.000953
# 4  ```json\n{\n    "report_type": "Other",\n    "...  0.000572
#
#   report_type_gpt has_sustainability_info_gpt  \
# 0           Other                       False
# 1   Annual Report                        True
# 2   Annual Report                        True
# 3           Other                       False
# 4           Other                       False
#
#                          company_name_gpt relation_type_gpt  \
# 0                        British Columbia       No Relation
# 1            Westlife Development Limited        Same group
# 2            Westlife Development Limited        Same group
# 3        Samuel Staples Elementary School       No Relation
# 4  Indira Gandhi National Open University       No Relation
#
#   is_match_company_name_gpt error n_tokenised_sentences  \
# 0                       0.0  None                  9802
# 1                       0.0  None                  6589
# 2                       0.0  None                  6589
# 3                       0.0  None                   785
# 4                       0.0  None                  1720
#
#   n_predicted_initiatives
# 0                      21
# 1                       3
# 2                       3
# 3                       2
# 4                       9
#
# [5 rows x 30 columns]

# %%
import pandas as pd

# 读取 parquet 文件
df = pd.read_parquet("../OneDrive_1_2025-6-9/symbols_table.parquet")


# 显示前几行
print(df.head())
# Out:
#                                        DocumentTitle         RIC  \
# 0  LUX IM European Equities DXL EUR, Open-End Fun...  LP65032832
# 1  LUX IM Pictet Asian Equities DXL EUR, Open-End...  LP65032835
# 2  LUX IM Morgan Stanley US Equities DXL EUR, Ope...  LP65032839
# 3  LUX IM Pictet Asian Equities DXBL EUR, Open-En...  LP65032840
# 4  JPM Europe Strategic Value I Dist EUR, Open-En...  LP65032853
#
#       IssueISIN    SEDOL FundClassLipperID TickerSymbol  Instrument CUSIP  \
# 0  LU0255269960     None          65032832         None  LP65032832  None
# 1  LU0255273566     None          65032835         None  LP65032835  None
# 2  LU0255272089     None          65032839         None  LP65032839  None
# 3  LU0255236019     None          65032840         None  LP65032840  None
# 4  LU0248049685  B11Z367          65032853         None  LP65032853  None
#
#   IssuerOAPermID TR.HQCountryCode  TR.InstrumentIsActive  \
# 0           None               LU                   True
# 1           None               LU                   True
# 2           None               LU                   True
# 3           None               LU                   True
# 4           None               LU                   True
#
#    TR.IsPrimaryInstrument
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
